# %%
import numpy as np
import pandas as pd
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)
vacc_df.head(5)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
 Mcountry=vacc_df[vacc_df.location.str.contains("Mexico")]
      
Mcountry
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 7765   Mexico      MEX  2020-12-24              2924.0             2924.0
# 7766   Mexico      MEX  2020-12-25                 NaN                NaN
# 7767   Mexico      MEX  2020-12-26                 NaN                NaN
# 7768   Mexico      MEX  2020-12-27              6824.0             6824.0
# 7769   Mexico      MEX  2020-12-28              9579.0             9579.0
# ...       ...      ...         ...                 ...                ...
# 7876   Mexico      MEX  2021-04-14          12407625.0         10310521.0
# 7877   Mexico      MEX  2021-04-15          12912963.0         10581915.0
# 7878   Mexico      MEX  2021-04-16          13421708.0         10837356.0
# 7879   Mexico      MEX  2021-04-17          13978181.0         11067294.0
# 7880   Mexico      MEX  2021-04-18          14240830.0         11196970.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
Mcountry.shape[0]
# Out:
# 116

# %%
m1=Mcountry.dropna(subset=['daily_vaccinations_raw'])
maxValue = m1['daily_vaccinations_raw'].idxmax()
print(maxValue)
m2=vacc_df.iloc[maxValue,[2]]
print(m2)
# Out:
# 7879
# date    2021-04-17
# Name: 7879, dtype: object

# %%
Mcountry.iloc[0:3,[0,2,6]]
#Mcountry.iloc[0:3,['daily_vaccinations','location']]
# Out:
#      location        date  daily_vaccinations_raw
# 7765   Mexico  2020-12-24                     NaN
# 7766   Mexico  2020-12-25                     NaN
# 7767   Mexico  2020-12-26                     NaN

# %%
Mcountry["daily_vaccinations_raw"].mean()
# Out:
# 130080.40776699029

# %%
Mcountry.dropna()
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 7787   Mexico      MEX  2021-01-15            417375.0           415417.0
# 7788   Mexico      MEX  2021-01-16            463246.0           461025.0
# 7789   Mexico      MEX  2021-01-17            472142.0           468708.0
# 7790   Mexico      MEX  2021-01-18            492529.0           485983.0
# 7791   Mexico      MEX  2021-01-19            498122.0           488513.0
# ...       ...      ...         ...                 ...                ...
# 7876   Mexico      MEX  2021-04-14          12407625.0         10310521.0
# 7877   Mexico      MEX  2021-04-15          12912963.0         10581915.0
# 7878   Mexico      MEX  2021-04-16          13421708.0         10837356.0
# 7879   Mexico      MEX  2021-04-17          13978181.0         11067294.0
# 7880   Mexico      MEX  2021-04-18          14240830.0         11196970.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
from scipy import stats
vph=Mcountry.dropna(subset=['people_vaccinated_per_hundred'])
vph1 = vph[vph.people_vaccinated_per_hundred != 0]
vph2=vph1['people_vaccinated_per_hundred'] 
#print(vph2)
stats.hmean(vph2)
# Out:
# 0.15229330390036813

# %%
median=Mcountry["daily_vaccinations_raw"].median()
mean=Mcountry["daily_vaccinations_raw"].mean()
if median > mean :
  print(median)
elif median==mean : 
    print("median=mean=",median)
else :
    print(mean)
# Out:
# 130080.40776699029

# %% [markdown]
# המדינה שבחרתי mexico

# %% [markdown]
# מטלה 2

# %%
Mcountry.head(3)
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 7765   Mexico      MEX  2020-12-24              2924.0             2924.0
# 7766   Mexico      MEX  2020-12-25                 NaN                NaN
# 7767   Mexico      MEX  2020-12-26                 NaN                NaN
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 7765                      NaN                     NaN                 NaN
# 7766                      NaN                     NaN              1300.0
# 7767                      NaN                     NaN              1300.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 7765                             0.0                            0.0
# 7766                             NaN                            NaN
# 7767                             NaN                            NaN
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# ...

# %% [markdown]
# מגד קבהא   ת.ד 315271106
# רואאה נסאר ת.ד 3233000414

# %%
r=pd.isnull(Mcountry).sum().idxmax()

m=pd.isnull(Mcountry).sum().max()
print(r,m)
# Out:
# people_fully_vaccinated 34

# %%
Mcountry_nan_d = pd.isnull(Mcountry['daily_vaccinations'])
Mcountry[Mcountry_nan_d]
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 7765   Mexico      MEX  2020-12-24              2924.0             2924.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 7765                      NaN                     NaN                 NaN
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 7765                             0.0                            0.0
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 7765                                  NaN                             NaN

# %%
Mcountry['daily_vaccinations'].fillna(method='bfill')
# Out:
# 7458      1300.0
# 7459      1300.0
# 7460      1300.0
# 7461      1300.0
# 7462      1664.0
#           ...
# 7566    337020.0
# 7567    345108.0
# 7568    368179.0
# 7569    331172.0
# 7570    261529.0
# Name: daily_vaccinations, Length: 113, dtype: float64

# %% [markdown]
# אני חושב שהם כמעט מחסנים כמו היום שעבר

# %%
import matplotlib.pyplot as plt
plt.hist(Mcountry['total_vaccinations'] )
plt.hist(Mcountry['people_vaccinated'] )
# Out:
# (array([49., 15.,  3.,  6.,  5.,  3.,  2.,  5.,  5.,  5.]),
#  array([2.92400000e+03, 1.12232860e+06, 2.24173320e+06, 3.36113780e+06,
#         4.48054240e+06, 5.59994700e+06, 6.71935160e+06, 7.83875620e+06,
#         8.95816080e+06, 1.00775654e+07, 1.11969700e+07]),
#  <BarContainer object of 10 artists>)

# %%
import statistics
med=Mcountry["people_fully_vaccinated_per_hundred"].median()
Mcountry.boxplot(column=['people_fully_vaccinated_per_hundred'])
print(med)
# Out:
# 0.06

# %% [markdown]
# הקו הירוק בתוך ה box plot הוא החציון

# %%
Mcountry['month']=pd.DatetimeIndex(Mcountry.date).month
M1=Mcountry.groupby('month')[['daily_vaccinations','people_vaccinated_per_hundred']].max()
print(M1)
# Out:
#        daily_vaccinations  people_vaccinated_per_hundred
# month
# 1                 57924.0                           0.49
# 2                140532.0                           1.47
# 3                247394.0                           5.36
# 4                368179.0                           7.52
# 12                 3695.0                           0.02
# <ipython-input-72-81ca35aea606>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mcountry['month']=pd.DatetimeIndex(Mcountry.date).month.copy()

# %%
M1.sort_values(by=['people_vaccinated_per_hundred'])
# Out:
#        daily_vaccinations  people_vaccinated_per_hundred
# month
# 12                 3695.0                           0.02
# 1                 57924.0                           0.49
# 2                140532.0                           1.47
# 3                247394.0                           5.36
# 4                368179.0                           7.52

# %%
עשר נקודות מתנה
תודה רבה רבה

# %% [markdown]
# מגד קבהא ת.ד 315271106
# רואאה נסאר ת.ד 3233000414
